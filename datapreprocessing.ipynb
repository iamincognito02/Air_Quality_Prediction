# %% [markdown]
# Import necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Reading the dataset

# %%
df = pd.read_csv('preprocessed_data.csv')

# %% [markdown]
# Printing head of the dataset

# %%
df.head()
# Out:
#    Unnamed: 0                     NAME  HUMIDITY  NO2_MAX  NO2_MIN  OZONE_MAX  \
# 0           1          BopadiSquare_65    19.995       59       54         15
# 1           2    Karve Statue Square_5    20.730       82       77         18
# 2           3     Lullanagar_Square_14    17.387       74       63         25
# 3           4      Hadapsar_Gadital_01    18.725      110      105          5
# 4           6  Goodluck Square_Cafe_23    19.896       82       78          6
#
#    OZONE_MIN  PM10_MAX  PM10_MIN  PM2_MAX  ...  CO_MAX  CO_MIN  CO2_MAX  \
# 0          0        22        19       18  ...     154     115      448
# 1          0        23        19       19  ...     124      69      441
# 2          0        25        21       20  ...     103      55       33
# 3          0        26        21       21  ...     128      95      482
# 4          0        26        23       21  ...     111      47      307
#
# ...

# %% [markdown]
# Printing tail of the dataset

# %%
df.tail()
# Out:
#        Unnamed: 0                                      NAME  HUMIDITY  \
# 83566      103201                       Hadapsar_Gadital_01    73.903
# 83567      103202  Dr Baba Saheb Ambedkar Sethu Junction_60    83.984
# 83568      103203                      Lullanagar_Square_14    74.412
# 83569      103204                     Karve Statue Square_5    75.912
# 83570      103205                   Pune Railway Station_28    72.648
#
#        NO2_MAX  NO2_MIN  OZONE_MAX  OZONE_MIN  PM10_MAX  PM10_MIN  PM2_MAX  \
# 83566        0        0         71         59         5         4        3
# 83567       37       34         17         10        20        15        8
# 83568       40       36         50         27         4         3        3
# 83569       66       65         18         15        11         9        5
# 83570      162      154          0          0         7         6        3
#
#        ...  CO_MAX  CO_MIN  CO2_MAX  CO2_MIN  TEMPRATURE_MAX  TEMPRATURE_MIN  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83571 entries, 0 to 83570
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          83571 non-null  int64
#  1   NAME                83571 non-null  object
#  2   HUMIDITY            83571 non-null  float64
#  3   NO2_MAX             83571 non-null  int64
#  4   NO2_MIN             83571 non-null  int64
#  5   OZONE_MAX           83571 non-null  int64
#  6   OZONE_MIN           83571 non-null  int64
#  7   PM10_MAX            83571 non-null  int64
#  8   PM10_MIN            83571 non-null  int64
#  9   PM2_MAX             83571 non-null  int64
#  10  PM2_MIN             83571 non-null  int64
#  11  SO2_MAX             83571 non-null  int64
#  12  SO2_MIN             83571 non-null  int64
#  13  CO_MAX              83571 non-null  int64
#  14  CO_MIN              83571 non-null  int64
#  15  CO2_MAX             83571 non-null  int64
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0      HUMIDITY       NO2_MAX       NO2_MIN     OZONE_MAX  \
# count   83571.000000  83571.000000  83571.000000  83571.000000  83571.000000
# mean    52099.427768     62.843741     72.999844     63.206459     16.502794
# std     31306.048385     22.060077     38.570837     34.417967     27.101078
# min         1.000000     10.166000      0.000000      0.000000      0.000000
# 25%     23398.000000     47.104500     46.000000     37.000000      0.000000
# 50%     52186.000000     68.259000     78.000000     66.000000      7.000000
# 75%     80659.500000     81.125000     97.000000     88.000000     24.000000
# max    103205.000000     97.359000    316.000000    315.000000    335.000000
#
#           OZONE_MIN      PM10_MAX      PM10_MIN       PM2_MAX       PM2_MIN  \
# count  83571.000000  83571.000000  83571.000000  83571.000000  83571.000000
# mean       4.112096     19.629417     15.044573     15.426332     12.029424
# ...

# %% [markdown]
# Printing
# ######    - Total number of columns
# ######    - Type of each column (categorical or numerical)
# ######    - Shape of the dataset

# %%
total_columns = len(df.columns)
print("Total number of columns in the dataset:", total_columns)


column_types = df.dtypes
categorical_columns = column_types[column_types == 'object'].index
numerical_columns = column_types[column_types != 'object'].index

print("\nColumn types:")
print("Categorical columns:", categorical_columns)
print("Numerical columns:", numerical_columns)

dataset_shape = df.shape
print("\nShape of the dataset (rows, columns):", dataset_shape)
# Out:
# Total number of columns in the dataset: 23
#
# Column types:
# Categorical columns: Index(['NAME', 'LASTUPDATEDATETIME'], dtype='object')
# Numerical columns: Index(['Unnamed: 0', 'HUMIDITY', 'NO2_MAX', 'NO2_MIN', 'OZONE_MAX',
#        'OZONE_MIN', 'PM10_MAX', 'PM10_MIN', 'PM2_MAX', 'PM2_MIN', 'SO2_MAX',
#        'SO2_MIN', 'CO_MAX', 'CO_MIN', 'CO2_MAX', 'CO2_MIN', 'TEMPRATURE_MAX',
#        'TEMPRATURE_MIN', 'UV_MAX', 'UV_MIN', 'AIR_PRESSURE'],
#       dtype='object')
#
# Shape of the dataset (rows, columns): (83571, 23)

# %% [markdown]
# Taking mean value of columns NO2_MAX and NO2_MIN

# %%
df['NO2_mean'] = np.mean(df[['NO2_MAX', 'NO2_MIN']], axis=1)

# %% [markdown]
# Printing column NO2_MAX NO2_MIN NO2_mean

# %%
print(df[['NO2_MAX', 'NO2_MIN', 'NO2_mean']])
# Out:
#        NO2_MAX  NO2_MIN  NO2_mean
# 0           59       54      56.5
# 1           82       77      79.5
# 2           74       63      68.5
# 3          110      105     107.5
# 4           82       78      80.0
# ...        ...      ...       ...
# 83566        0        0       0.0
# 83567       37       34      35.5
# 83568       40       36      38.0
# 83569       66       65      65.5
# 83570      162      154     158.0
#
# [83571 rows x 3 columns]

# %%
print(df)
# Out:
#        Unnamed: 0                                      NAME  HUMIDITY  \
# 0               1                           BopadiSquare_65    19.995
# 1               2                     Karve Statue Square_5    20.730
# 2               3                      Lullanagar_Square_14    17.387
# 3               4                       Hadapsar_Gadital_01    18.725
# 4               6                   Goodluck Square_Cafe_23    19.896
# ...           ...                                       ...       ...
# 83566      103201                       Hadapsar_Gadital_01    73.903
# 83567      103202  Dr Baba Saheb Ambedkar Sethu Junction_60    83.984
# 83568      103203                      Lullanagar_Square_14    74.412
# 83569      103204                     Karve Statue Square_5    75.912
# 83570      103205                   Pune Railway Station_28    72.648
#
#        NO2_MAX  NO2_MIN  OZONE_MAX  OZONE_MIN  PM10_MAX  PM10_MIN  PM2_MAX  \
# ...

# %% [markdown]
# Removing 'NO2_MAX' and 'NO2_MIN' columns

# %%
df.drop(columns=['NO2_MAX', 'NO2_MIN'], inplace=True)

# %%
print(df)
# Out:
#        Unnamed: 0                                      NAME  HUMIDITY  \
# 0               1                           BopadiSquare_65    19.995
# 1               2                     Karve Statue Square_5    20.730
# 2               3                      Lullanagar_Square_14    17.387
# 3               4                       Hadapsar_Gadital_01    18.725
# 4               6                   Goodluck Square_Cafe_23    19.896
# ...           ...                                       ...       ...
# 83566      103201                       Hadapsar_Gadital_01    73.903
# 83567      103202  Dr Baba Saheb Ambedkar Sethu Junction_60    83.984
# 83568      103203                      Lullanagar_Square_14    74.412
# 83569      103204                     Karve Statue Square_5    75.912
# 83570      103205                   Pune Railway Station_28    72.648
#
#        OZONE_MAX  OZONE_MIN  PM10_MAX  PM10_MIN  PM2_MAX  PM2_MIN  SO2_MAX  \
# ...

# %% [markdown]
# Removing not necessary columns

# %%
df.drop(columns=['OZONE_MAX', 'OZONE_MIN'])
# Out:
#        Unnamed: 0                                      NAME  HUMIDITY  \
# 0               1                           BopadiSquare_65    19.995
# 1               2                     Karve Statue Square_5    20.730
# 2               3                      Lullanagar_Square_14    17.387
# 3               4                       Hadapsar_Gadital_01    18.725
# 4               6                   Goodluck Square_Cafe_23    19.896
# ...           ...                                       ...       ...
# 83566      103201                       Hadapsar_Gadital_01    73.903
# 83567      103202  Dr Baba Saheb Ambedkar Sethu Junction_60    83.984
# 83568      103203                      Lullanagar_Square_14    74.412
# 83569      103204                     Karve Statue Square_5    75.912
# 83570      103205                   Pune Railway Station_28    72.648
#
#        PM10_MAX  PM10_MIN  PM2_MAX  PM2_MIN  SO2_MAX  SO2_MIN  CO_MAX  CO_MIN  \
# ...

# %% [markdown]
# Taking mean value of columns PM10_MAX and PM10_MIN

# %%
df['PM10_mean'] = np.mean(df[['PM10_MAX', 'PM10_MIN']], axis=1)

# %% [markdown]
# Taking mean value of columns PM2_MAX and PM2_MIN

# %%
df['PM2_mean'] = np.mean(df[['PM2_MAX', 'PM2_MIN']], axis=1)

# %% [markdown]
# Taking mean value of columns SO2_MAX and SO2_MIN

# %%
df['SO2_mean'] = np.mean(df[['SO2_MAX', 'SO2_MIN']], axis=1)

# %%
print(df)
# Out:
#        Unnamed: 0                                      NAME  HUMIDITY  \
# 0               1                           BopadiSquare_65    19.995
# 1               2                     Karve Statue Square_5    20.730
# 2               3                      Lullanagar_Square_14    17.387
# 3               4                       Hadapsar_Gadital_01    18.725
# 4               6                   Goodluck Square_Cafe_23    19.896
# ...           ...                                       ...       ...
# 83566      103201                       Hadapsar_Gadital_01    73.903
# 83567      103202  Dr Baba Saheb Ambedkar Sethu Junction_60    83.984
# 83568      103203                      Lullanagar_Square_14    74.412
# 83569      103204                     Karve Statue Square_5    75.912
# 83570      103205                   Pune Railway Station_28    72.648
#
#        OZONE_MAX  OZONE_MIN  PM10_MAX  PM10_MIN  PM2_MAX  PM2_MIN  SO2_MAX  \
# ...

# %% [markdown]
# Removing this columns as I have taken their means.

# %%
df= df.drop(columns=['PM10_MIN', 'PM10_MAX', 'PM2_MAX', 'PM2_MIN', 'SO2_MAX', 'SO2_MIN','OZONE_MAX', 'OZONE_MIN'])

# %%
df
# Out:
#        Unnamed: 0                                      NAME  HUMIDITY  CO_MAX  \
# 0               1                           BopadiSquare_65    19.995     154
# 1               2                     Karve Statue Square_5    20.730     124
# 2               3                      Lullanagar_Square_14    17.387     103
# 3               4                       Hadapsar_Gadital_01    18.725     128
# 4               6                   Goodluck Square_Cafe_23    19.896     111
# ...           ...                                       ...       ...     ...
# 83566      103201                       Hadapsar_Gadital_01    73.903     119
# 83567      103202  Dr Baba Saheb Ambedkar Sethu Junction_60    83.984      78
# 83568      103203                      Lullanagar_Square_14    74.412      43
# 83569      103204                     Karve Statue Square_5    75.912     112
# 83570      103205                   Pune Railway Station_28    72.648      46
#
# ...

# %%
print(df)
# Out:
#        Unnamed: 0                                      NAME  HUMIDITY  CO_MAX  \
# 0               1                           BopadiSquare_65    19.995     154
# 1               2                     Karve Statue Square_5    20.730     124
# 2               3                      Lullanagar_Square_14    17.387     103
# 3               4                       Hadapsar_Gadital_01    18.725     128
# 4               6                   Goodluck Square_Cafe_23    19.896     111
# ...           ...                                       ...       ...     ...
# 83566      103201                       Hadapsar_Gadital_01    73.903     119
# 83567      103202  Dr Baba Saheb Ambedkar Sethu Junction_60    83.984      78
# 83568      103203                      Lullanagar_Square_14    74.412      43
# 83569      103204                     Karve Statue Square_5    75.912     112
# 83570      103205                   Pune Railway Station_28    72.648      46
#
# ...

# %% [markdown]
# Taking mean value of columns CO_MAX and CO_MIN

# %%
df['CO_mean'] = np.mean(df[['CO_MAX', 'CO_MIN']], axis=1)

# %% [markdown]
# Taking mean value of columns CO2_MAX and CO2_MIN

# %%
df['CO2_mean'] = np.mean(df[['CO2_MAX', 'CO2_MIN']], axis=1)

# %% [markdown]
# Removing this columns as I have taken their means.

# %%
df= df.drop(columns=['CO_MIN', 'CO_MAX', 'CO2_MAX', 'CO2_MIN'])

# %%
df
# Out:
#        Unnamed: 0                                      NAME  HUMIDITY  \
# 0               1                           BopadiSquare_65    19.995
# 1               2                     Karve Statue Square_5    20.730
# 2               3                      Lullanagar_Square_14    17.387
# 3               4                       Hadapsar_Gadital_01    18.725
# 4               6                   Goodluck Square_Cafe_23    19.896
# ...           ...                                       ...       ...
# 83566      103201                       Hadapsar_Gadital_01    73.903
# 83567      103202  Dr Baba Saheb Ambedkar Sethu Junction_60    83.984
# 83568      103203                      Lullanagar_Square_14    74.412
# 83569      103204                     Karve Statue Square_5    75.912
# 83570      103205                   Pune Railway Station_28    72.648
#
#        TEMPRATURE_MAX  TEMPRATURE_MIN  UV_MAX  UV_MIN  AIR_PRESSURE  \
# ...

# %% [markdown]
# Spliting 'LASTUPDATEDATETIME' into separate date and time columns

# %%
df[['Date', 'Time']] = df['LASTUPDATEDATETIME'].str.split(' ', expand=True)

# %%
print(df)
# Out:
#        Unnamed: 0                                      NAME  HUMIDITY  \
# 0               1                           BopadiSquare_65    19.995
# 1               2                     Karve Statue Square_5    20.730
# 2               3                      Lullanagar_Square_14    17.387
# 3               4                       Hadapsar_Gadital_01    18.725
# 4               6                   Goodluck Square_Cafe_23    19.896
# ...           ...                                       ...       ...
# 83566      103201                       Hadapsar_Gadital_01    73.903
# 83567      103202  Dr Baba Saheb Ambedkar Sethu Junction_60    83.984
# 83568      103203                      Lullanagar_Square_14    74.412
# 83569      103204                     Karve Statue Square_5    75.912
# 83570      103205                   Pune Railway Station_28    72.648
#
#        TEMPRATURE_MAX  TEMPRATURE_MIN  UV_MAX  UV_MIN  AIR_PRESSURE  \
# ...

# %% [markdown]
# Removing the LASTUPDATEDATETIME column.

# %%
df= df.drop(columns=['LASTUPDATEDATETIME'])

# %%
df
# Out:
#        Unnamed: 0                                      NAME  HUMIDITY  \
# 0               1                           BopadiSquare_65    19.995
# 1               2                     Karve Statue Square_5    20.730
# 2               3                      Lullanagar_Square_14    17.387
# 3               4                       Hadapsar_Gadital_01    18.725
# 4               6                   Goodluck Square_Cafe_23    19.896
# ...           ...                                       ...       ...
# 83566      103201                       Hadapsar_Gadital_01    73.903
# 83567      103202  Dr Baba Saheb Ambedkar Sethu Junction_60    83.984
# 83568      103203                      Lullanagar_Square_14    74.412
# 83569      103204                     Karve Statue Square_5    75.912
# 83570      103205                   Pune Railway Station_28    72.648
#
#        TEMPRATURE_MAX  TEMPRATURE_MIN  UV_MAX  UV_MIN  AIR_PRESSURE  NO2_mean  \
# ...

# %% [markdown]
# Get unique values from the 'NAME' column

# %%
unique_values = df['NAME'].unique()

# %% [markdown]
# Printing the unique values.

# %%
print(unique_values)
# Out:
# ['BopadiSquare_65' 'Karve Statue Square_5' 'Lullanagar_Square_14'
#  'Hadapsar_Gadital_01' 'Goodluck Square_Cafe_23'
#  'Chitale Bandhu Corner_41' 'Pune Railway Station_28'
#  'Rajashri_Shahu_Bus_stand_19' 'PMPML_Bus_Depot_Deccan_15'
#  'Dr Baba Saheb Ambedkar Sethu Junction_60']

# %% [markdown]
# Encoding unique values in column 'NAME' with number (Converting categorical value to numerical).

# %%
df['NAME'] = df['NAME'].replace({'BopadiSquare_65': 1,'Karve Statue Square_5': 2,'Lullanagar_Square_14': 3, 'Hadapsar_Gadital_01': 4, 'Goodluck Square_Cafe_23': 5, 'Chitale Bandhu Corner_41': 6, 'Pune Railway Station_28':7, 'Rajashri_Shahu_Bus_stand_19': 8,'PMPML_Bus_Depot_Deccan_15':9,  'Dr Baba Saheb Ambedkar Sethu Junction_60':10})

# %%
df
# Out:
#        Unnamed: 0  NAME  HUMIDITY  TEMPRATURE_MAX  TEMPRATURE_MIN  UV_MAX  \
# 0               1     1    19.995              41              24     5.3
# 1               2     2    20.730              39              25     0.8
# 2               3     3    17.387              40              24     0.5
# 3               4     4    18.725              38              26     1.3
# 4               6     5    19.896              40              26     2.6
# ...           ...   ...       ...             ...             ...     ...
# 83566      103201     4    73.903              27              24     0.1
# 83567      103202    10    83.984              28              24     0.1
# 83568      103203     3    74.412              27              23     0.6
# 83569      103204     2    75.912              27              24     0.0
# 83570      103205     7    72.648              28              24     0.9
#
#        UV_MIN  AIR_PRESSURE  NO2_mean  PM10_mean  PM2_mean  SO2_mean  CO_mean  \
# ...

# %% [markdown]
# Saving all the above preprocessing work to 'preprocessed_data_2.csv'

# %%
df.to_csv('preprocessed_data_2.csv', index=False)

# %% [markdown]
# Finding the correlation of the columns 'HUMIDITY', 'TEMPRATURE_MAX', 'UV_MAX' and 'AIR_PRESSURE'

# %%
correlation = df[['HUMIDITY', 'TEMPRATURE_MAX', 'UV_MAX', 'AIR_PRESSURE']].corr()

# %%
correlation
# Out:
#                 HUMIDITY  TEMPRATURE_MAX    UV_MAX  AIR_PRESSURE
# HUMIDITY        1.000000       -0.768882 -0.488870     -0.047833
# TEMPRATURE_MAX -0.768882        1.000000  0.304283      0.059287
# UV_MAX         -0.488870        0.304283  1.000000      0.045911
# AIR_PRESSURE   -0.047833        0.059287  0.045911      1.000000

# %% [markdown]
# Finding the correlation of the columns 'NO2_mean', 'PM10_mean', 'PM2_mean', 'SO2_mean','CO_mean' and 'CO2_mean'

# %%
correlation1 = df[['NO2_mean', 'PM10_mean', 'PM2_mean', 'SO2_mean','CO_mean', 'CO2_mean']].corr()

# %%
correlation1
# Out:
#            NO2_mean  PM10_mean  PM2_mean  SO2_mean   CO_mean  CO2_mean
# NO2_mean   1.000000   0.235287  0.236753  0.313384  0.271661 -0.352165
# PM10_mean  0.235287   1.000000  0.962817 -0.003056  0.422507  0.021409
# PM2_mean   0.236753   0.962817  1.000000 -0.007879  0.485129 -0.012723
# SO2_mean   0.313384  -0.003056 -0.007879  1.000000  0.115911  0.025939
# CO_mean    0.271661   0.422507  0.485129  0.115911  1.000000  0.250428
# CO2_mean  -0.352165   0.021409 -0.012723  0.025939  0.250428  1.000000
